# %%
import json
from datetime import datetime, timedelta,date
import pandas as pd
from functools import reduce
import numpy as np 
import os.path

class ReportTM:
    def __init__(self):
        pass

    def generate_DF(self,name_file):
        with open('data/'+name_file, encoding='utf-8') as fh:
            data = json.load(fh)

        price_date_name = 'currentPrice_'+str(name_file[:-5])
        Data_products = {
            "id" : [],
            'colorDescription' : [],
            'portrait_url' : [],
            'squarishURL' : [],
            'Stock' : [],
            'isNew' : [],
            price_date_name : [],
            'fullPrice' : [],
            'subtitle' : [],
            'title' : [],
            'date':[]
        }

        for product in data:
            Data_products['id'].append(product['id'])
            Data_products['colorDescription'].append(product['colorDescription'])
            Data_products['portrait_url'].append(product['images']['portraitURL'])
            Data_products['squarishURL'].append(product['images']['squarishURL'])
            Data_products['Stock'].append(product['inStock'])
            Data_products['isNew'].append(product['colorways'][0]['isNew'])
            Data_products[price_date_name].append(product['price']['currentPrice'])
            Data_products['fullPrice'].append(product['price']['fullPrice'])
            Data_products['subtitle'].append(product['subtitle'])
            Data_products['title'].append(product['title'])
            Data_products['date'].append(name_file[:-5])
        
        return pd.DataFrame(Data_products)

    def generate_time_serie(self,*files):
        array_dataframes =[]
        for file in files:
            with open('data/'+file, encoding='utf-8') as fh:
                data = json.load(fh)

            price_date_name = file[:-5]
            Data_products = {
                "id" : [],
                price_date_name : []

            }

            for product in data:
                Data_products['id'].append(product['id'])
                Data_products[price_date_name].append(product['price']['currentPrice'])
            array_dataframes.append(pd.DataFrame(Data_products))

        # merge a la lista de dataframes

        df_final = reduce(lambda left,right: pd.merge(left,right,on='id', how='outer'), array_dataframes)

        return df_final
    
    def check_changes_2days(self, day):
    
        #obtenemos el dia anterior a la fecha dada
        date = datetime.strptime(day, "%Y-%m-%d")
        modified_date = date - timedelta(days=1)
        prev_day = datetime.strftime(modified_date, "%Y-%m-%d")
        #comprobamos que existan archivos para los dos dias
        day_file = day +'.json'
        prev_day_file = prev_day+'.json'
        if os.path.isfile('data/'+day_file) and os.path.isfile('data/'+prev_day_file) :
            df_time = self.generate_time_serie(prev_day_file,day_file)
            df_time['change'] = df_time[prev_day_file[:-5]] - df_time[day_file[:-5]]
            
            return df_time.loc[df_time['change']>0].sort_values(by= 'change',ascending=False)
            #
        else:
            raise ValueError(
                    "Nombres de archivo no validos. "
                        f"Only one file per ZIP: {prev_day_file,day_file}"
                    )

# %%
class reporteLIQ(ReportTM):
    def __init__(self,path):
        self.path = path
        
    def generate_DF(self,name_file):
        with open(self.path+name_file, encoding='utf-8') as fh:
            data = json.load(fh)

        price_date_name = 'currentPrice_'+str(name_file[:-5])
        Data_products = {
            "id" : [],
            'colorDescription' : [],
            'portrait_url' : [],
            'squarishURL' : [],
            'Stock' : [],
            'isNew' : [],
            price_date_name : [],
            'fullPrice' : [],
            'subtitle' : [],
            'title' : [],
            'date':[]
        }

        for product in data:
            Data_products['id'].append(product['id'])
            Data_products['colorDescription'].append(product['colorDescription'])
            Data_products['portrait_url'].append(product['images']['portraitURL'])
            Data_products['squarishURL'].append(product['images']['squarishURL'])
            Data_products['Stock'].append(product['inStock'])
            Data_products['isNew'].append(product['colorways'][0]['isNew'])
            Data_products[price_date_name].append(product['price']['currentPrice'])
# 152  36a324f6-9571-3092-bd61-eb248ad9cd56
# 153  3c96bbec-1015-30e9-8dac-d071266e08f1
# 154  b54b65b0-8f6a-3da3-8c50-78b65b583fc6
# 155  2fb4a488-d1db-37dc-a1e6-cb01ddc313ea
# 156  32dfe11f-117b-3df8-9443-1cd78f96332b
# 157  3ad68c52-8e4b-3a17-9805-ad5cec3fa404
# 158  ec798b89-6f68-3b0c-88a8-d13f80f05aae
# 159  b7c8295b-c7eb-382d-8c0b-5a2cb8c06087
# 160  d4db046a-ff29-303f-aad9-5e359cd00d36
# 161  8efc3f3f-1b11-35d5-9489-2380a56f18fd
# 162  767da377-2a2d-3713-b437-10dbbc092de5
# 163  b290626a-e1c7-34c1-9dfd-ed3004ae98c7
# 164  d1f94fb9-a50d-3065-a31f-1a4bbb08a56a
#
#                                       colorDescription  \
# 0                                Negro/Antracita/Negro
# 1        Negro/Blanco/Azul universitario/Naranja láser
# 2                                    Negro/Negro/Negro
# 3             Negro/Gris fútbol/Vainilla Pálido/Blanco
# 4                Negro/Naranja máximo/Plata metalizado
# 5                       Blanco/Azul carrera/Volt/Negro
# 6                                   Veneno limón/Negro
# 7                           Blanco/Blanco/Hipercarmesí
# 8                           Blanco/Negro/Carmesí láser
# 9                           Negro/Naranja total/Blanco
# 10               Blanco/Tinte Platino/Gris Metro/Negro
# 11                         Negro/Verde eléctrico/Negro
# 12     Blanco cáscara de huevo/Blanco cáscara de huevo
# 13                          Negro/Naranja total/Blanco
# 14                         Negro/Gris lobo/Blanco/Volt
# 15            Oro universitario/Blanco/Negro/Rojo team
# 16                                Negro/Gris lobo/Volt
# 17               Verde Strike/Negro/Platino metalizado
# 18                           Negro/Antracita/Antracita
# 19   Azul royal intenso/Rojo órbita/Negro/Agua Fant...
# 20                          Carmesí láser/Blanco/Negro
# 21      Negro/Rojo órbita/Violeta enérgico/Gris oscuro
# 22   Hueso claro/Oro metalizado/Rojo universitario/...
# 23           Negro/Blanco/Rojo gimnasio/Oro metalizado
# 24   Hueso claro/Oro metalizado/Rojo universitario/...
# 25           Negro/Blanco/Rojo gimnasio/Oro metalizado
# 26                Carmesí láser/Negro/Plata metalizado
# 27                                         Negro/Negro
# 28                      Bruma Lavanda/Bruma lila/Negro
# 29                                   Negro/Volt/Blanco
# ..                                                 ...
# 135        Blanco/Gris lobo/Naranja césped/Trueno azul
# 136         Carmesí láser/Negro/Negro/Plata metalizado
# 137                         Negro/Blanco/Rojo gimnasio
# 138                     Blanco/Azul carrera/Volt/Negro
# 139                             Negro/Multicolor/Negro
# 140  Gris vasto/Azul señal/Volt resplandor/Azul oscuro
# 141                    Platino puro/Hiperuva/Oro cañón
# 142                                       Blanco/Negro
# 143        Secuoya/Limón brillante/Burdeos/Morado vivo
# 144                                 Veneno limón/Negro
# 145          Negro/Rojo universitario/Gris lobo/Blanco
# 146                          Negro/Vela/Amanecer ámbar
# 147                                 Veneno limón/Negro
# 148          Azul pálido/Negro/Vela/Azul universitario
# 149  Royal intenso/Azul marino universitario/Vela/N...
# 150                    Gris oscuro/Amarillo opti/Negro
# 151                       Gris lobo/Sigilo/Gris oscuro
# 152                                 Gris azulado/Negro
# 146  https://static.nike.com/a/images/t_default/soy...  False  False
# 147  https://static.nike.com/a/images/t_default/i1-...   True  False
# 148  https://static.nike.com/a/images/t_default/xmi...  False  False
# 149  https://c.static-nike.com/a/images/t_default/z...  False  False
# 150  https://c.static-nike.com/a/images/t_default/a...   True  False
# 151  https://c.static-nike.com/a/images/t_default/k...  False  False
# 152  https://c.static-nike.com/a/images/t_default/n...   True  False
# 153  https://static.nike.com/a/images/t_default/kbf...   True  False
# 154  https://c.static-nike.com/a/images/t_default/v...   True  False
# 155  https://c.static-nike.com/a/images/t_default/q...   True  False
# 156  https://c.static-nike.com/a/images/t_default/h...   True  False
# 157  https://static.nike.com/a/images/t_default/izx...   True  False
# 158  https://static.nike.com/a/images/t_default/w3j...   True  False
# 159  https://static.nike.com/a/images/t_default/4b2...   True  False
# 160  https://static.nike.com/a/images/t_default/n1x...   True  False
# 161  https://static.nike.com/a/images/t_default/ds6...   True  False
# 162  https://c.static-nike.com/a/images/t_default/f...   True  False
# 163  https://c.static-nike.com/a/images/t_default/c...   True  False
# 164  https://static.nike.com/a/images/t_default/upe...  False  False
#
#      currentPrice_2020-07-11  fullPrice  \
# 0                       2878       3599
# 1                       2798       3499
# 2                       2478       3099
# 3                       2078       2599
# 4                       2118       2649
# 5                       1618       1799
# 6                       4878       6098
# 7                       1758       2199
# 8                       1618       1798
# 9                       1618       1798
# 10                      2798       3498
# 11                      2718       3399
# 12                      2238       2799
# 13                      3838       4798
# 14                      2318       2898
# 15                      1518       1899
# 16                      3038       3799
# 17                      1518       1898
# 18                      1438       1799
# 19                      3918       4899
# 20                      3918       4898
# 21                      2238       3199
# 22                      1598       1998
# 23                      2078       2598
# 24                      1598       1998
# 25                      2078       2598
# 26                      2398       2998
# 27                      4078       5098
# 28                      2438       3049
# 29                      1598       1998
# ..                       ...        ...
# 135                     1558       1949
# 136                     2398       2998
# 137                     1198       1499
# 138                     4398       5498
# 139                     1038       1299
# 140                     2158       2699
# 141                     3118       3899
# 142                     1918       2399
# 143                     1918       2399
# 144                     2958       3699
# 145                     2798       3498
# 146                     1758       2199
# 147                     2958       3699
# 148                     2318       2899
# 149                     2878       3599
# 150                     2078       2599
# 151                     1758       2199
# 152                     1438       1799
# 153                     2838       3549
# 154                     2318       2898
# 155                     1598       1999
# 156                     2638       3298
# 157                     1118       1399
# 158                     2158       2699
# 159                     1398       1749
# 160                     4398       5498
# 161                     1518       1898
# 162                     1238       1549
# 163                     1118       1399
# 164                     3838       4799
#
#                                               subtitle  \
# 0                                  Calzado para hombre
# 1                       Calzado de running para hombre
# 2                                  Calzado para hombre
# 3                                              Calzado
# 4                                              Calzado
# 5               Calzado de fútbol para cancha cubierta
# 6                 Calzado de fútbol para terreno firme
# 7                 Calzado de fútbol para terreno firme
# 8       Calzado de fútbol para césped deportivo (turf)
# 9               Calzado de fútbol para cancha cubierta
# 10                      Calzado de running para hombre
# 11                                             Calzado
# 12                                 Calzado para hombre
# 13                Calzado de fútbol para terreno firme
# 14                      Calzado de running para hombre
# 15                                             Calzado
# 16                                 Calzado para hombre
# 17            Calzado de fútbol para césped artificial
# 18                Calzado de entrenamiento para hombre
# 19                                  Calzado de running
# 20               Calzado de fútbol para terreno blando
# 21                                 Calzado para hombre
# 22                                             Calzado
# 23                      Calzado de running para hombre
# 24                                             Calzado
# 25                      Calzado de running para hombre
# 26                Calzado de fútbol para terreno firme
# 27            Calzado de fútbol para césped artificial
# 28                                 Calzado para hombre
# 29   Calzado de tenis para cancha de arcilla para h...
# ..                                                 ...
# 135                                Calzado para hombre
# 136            Calzado de fútbol para pasto artificial
# 137                    Calzado de skateboarding unisex
# 138           Calzado de fútbol para césped artificial
# 139                                            Chancla
# 140        Calzado de tenis de cancha dura para hombre
# 141                                Calzado para hombre
# 142                                Calzado para hombre
# 143                                Calzado para hombre
# 144  Calzado de fútbol para césped deportivo artifi...
# 145                              Calzado de básquetbol
# 146                                Calzado para hombre
# 147             Calzado de fútbol para cancha cubierta
# 148                                Calzado para hombre
# 149                                Calzado para hombre
# 150               Calzado de fútbol para terreno firme
# 151                     Calzado de running para hombre
# 152  Calzado de entrenamiento y para el gimnasio pa...
# 153                                Calzado para hombre
# 154                     Calzado de running para hombre
# 155                                Calzado para hombre
# 156                                 Calzado de running
# 157                     Calzado de running para hombre
# 158                                Calzado para hombre
# 159                                Calzado para hombre
# 160              Calzado de fútbol para terreno blando
# 161              Calzado de fútbol para terreno blando
# 162                                     Calzado unisex
# 163                                Calzado para hombre
# 164                                Calzado para hombre
#
#                                                  title        date
# 0                                     Nike Air Max 720  2020-07-11
# 1                             Nike Joyride Run Flyknit  2020-07-11
# 2                             Nike Air Max Tailwind IV  2020-07-11
# 3                                   Nike Signal D/MS/X  2020-07-11
# 4                                         Nike Shox R4  2020-07-11
# 5        Nike Mercurial Vapor 13 Academy Neymar Jr. IC  2020-07-11
# 6               Nike Mercurial Superfly 7 Elite MDS FG  2020-07-11
# 7                                   Nike Premier II FG  2020-07-11
# 8                   Nike Mercurial Vapor 13 Academy TF  2020-07-11
# 9                               Nike Premier 2 Sala IC  2020-07-11
# 10                            Nike Joyride Run Flyknit  2020-07-11
# 11                    Nike Air Max 270 Special Edition  2020-07-11
# 12                                 Nike Air Max2 Light  2020-07-11
# 13                       Nike Tiempo Legend 8 Elite FG  2020-07-11
# 14                           Nike Epic React Flyknit 2  2020-07-11
# 15                                Nike Air Tailwind 79  2020-07-11
# 16                                   Nike Air Max 2015  2020-07-11
# 17        Nike Phantom Vision 2 Academy Dynamic Fit AG  2020-07-11
# 18                        Nike Air Max Alpha Trainer 2  2020-07-11
# 19                            Nike Vaporfly 4% Flyknit  2020-07-11
# 20   Nike Tiempo Legend 8 Elite SG-PRO Anti-Clog Tr...  2020-07-11
# 21                                    Nike N110 D/MS/X  2020-07-11
# 22                                         Nike P-6000  2020-07-11
# 23                               Nike Joyride Dual Run  2020-07-11
# 24                                         Nike P-6000  2020-07-11
# 25                               Nike Joyride Dual Run  2020-07-11
# 26                           Nike Phantom Venom Pro FG  2020-07-11
# 27                Nike Mercurial Vapor 13 Elite AG-PRO  2020-07-11
# 28                                    Nike Daybreak SP  2020-07-11
# 29                         NikeCourt Air Zoom Prestige  2020-07-11
# ..                                                 ...         ...
# 135                               Nike Cortez Kenny IV  2020-07-11
# 136                      Nike Phantom Venom Pro AG-Pro  2020-07-11
# 137                                   Nike SB Portmore  2020-07-11
# 138    Nike Mercurial Vapor 13 Elite Neymar Jr. AG-PRO  2020-07-11
# 139                            Nike Benassi JDI BETRUE  2020-07-11
# 140                              NikeCourt Zoom Cage 3  2020-07-11
# 141                             Nike Air Max 720 (OBJ)  2020-07-11
# 142                             Jordan Flight Origin 4  2020-07-11
# 143                                     Nike Air Skarn  2020-07-11
# 144             Nike Mercurial Superfly 7 Elite MDS TF  2020-07-11
# 145                              Nike Air Force Max II  2020-07-11
# 146                                    Nike Blazer '77  2020-07-11
# 147             Nike Mercurial Superfly 7 Elite MDS IC  2020-07-11
# 148                          Air Jordan Legacy 312 Low  2020-07-11
# 149                    Nike React Vapor Street Flyknit  2020-07-11
# 150                               Nike Legend 7 Pro FG  2020-07-11
# 151                                  Nike Air Max Fury  2020-07-11
# 152                         Nike Air Max Alpha Trainer  2020-07-11
# 153                        Nike Air Max Tailwind IV SP  2020-07-11
# 154                          Nike Epic React Flyknit 2  2020-07-11
# 155                             Nike Air Max Sequent 2  2020-07-11
# 156                              Nike Zoom Fly SP Fast  2020-07-11
# 157                                 Nike Downshifter 9  2020-07-11
# 158                           Nike React Element 55 SE  2020-07-11
# 159                                       Nike Zoom 2K  2020-07-11
# 160  Nike Mercurial Vapor 13 Elite MDS SG-PRO Anti-...  2020-07-11
# 161  Nike PhantomVSN Academy Dynamic Fit SG-Pro Ant...  2020-07-11
# 162                          Nike Classic Cortez Nylon  2020-07-11
# 163                                         Nike Viale  2020-07-11
# 164                          Air Jordan 3 Retro Tinker  2020-07-11
#
# [165 rows x 11 columns]

# %%
class Animal:
    def __init__(self, especie, edad):
        self.especie = especie
        self.edad = edad        
    def hablar(self):
        pass

    def moverse(self):
        pass

    def describeme(self):
        print("Soy un Animal del tipo", type(self).__name__)

# %%
class Perro(Animal):
    def __init__(self, especie, edad, dueño):
        super().__init__(especie, edad)
        self.dueño = dueño

# %%
a = Perro('h0', 23, 'j')

# %%
from pandas import DataFrame 

Dates = {'Day': [1,2,3,4,5], 
        'Month': ['Jun','Jul','Aug','Sep','Oct'], 
        'Year': [2016,2017,2018,2019,2020]} 
Dates1 = {'Day': [1,2,3,4,5], 
        'Month': ['Jun','Jul','Aug','Sep','Oct'], 
        'Year': [201,207,218,219,220]}

# %%
df = pd.DataFrame(Dates)
df_1 = pd.DataFrame(Dates1)

# %%
df
# Out:
#    Day Month  Year
# 0    1   Jun  2016
# 1    2   Jul  2017
# 2    3   Aug  2018
# 3    4   Sep  2019
# 4    5   Oct  2020

# %%
df_1
# Out:
#    Day Month  Year
# 0    1   Jun   201
# 1    2   Jul   207
# 2    3   Aug   218
# 3    4   Sep   219
# 4    5   Oct   220

# %%
pd.concat([df, df_1['Year']], axis=1)
# Out:
#    Day Month  Year  Year
# 0    1   Jun  2016   201
# 1    2   Jul  2017   207
# 2    3   Aug  2018   218
# 3    4   Sep  2019   219
# 4    5   Oct  2020   220

# %%
a =[df,df_1]

# %%
for elemn in a:
    base = a[0]
    x = pd.concat([df,elemn['Year']], axis=1)

# %%
x
# Out:
#    Day Month  Year  Year
# 0    1   Jun  2016   201
# 1    2   Jul  2017   207
# 2    3   Aug  2018   218
# 3    4   Sep  2019   219
# 4    5   Oct  2020   220
